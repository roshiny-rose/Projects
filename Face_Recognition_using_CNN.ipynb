# %%
import cv2
from google.colab.patches import cv2_imshow

# Define the path to your image file
image_path = '/BillGates.jpg'

# Load the pre-trained face detection model
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Read the input image
input_image = cv2.imread(image_path)

# Check if the image is loaded properly
if input_image is None:
    print("Error loading image. Please check the image path.")
else:
    # Convert the image to grayscale (required for face detection)
    gray = cv2.cvtColor(input_image, cv2.COLOR_BGR2GRAY)

    # Perform face detection
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    # Draw a rectangle around the first detected face (if any)
    if len(faces) > 0:
        (x, y, w, h) = faces[0]
        cv2.rectangle(input_image, (x, y), (x+w, y+h), (0, 255, 0), 2)

    # Display the input image with face outline
    cv2_imshow(input_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=560x680>
